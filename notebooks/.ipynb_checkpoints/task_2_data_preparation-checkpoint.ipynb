# %%
# task_2_data_preparation.ipynb

import pandas as pd
import os

# Define the correct local directory
data_dir = "C:\\Users\\ayedr\\week-1\\data\\yfinance_data"

# List of stock Excel files
stock_files = ["AAPL_historical_data.xlsx", "AMZN_historical_data.xlsx", "GOOG_historical_data.xlsx", "MSFT_historical_data.xlsx", "NVDA_historical_data.xlsx", "TSLA_historical_data.xlsx"]

# Dictionary to hold each stock's data
stock_data = {}

for file in stock_files:
    stock_name = file.split(".")[0]
    file_path = os.path.join(data_dir, file)

    # Load and preprocess
    df = pd.read_excel(file_path)
    df['Date'] = pd.to_datetime(df['Date'])  # Ensure Date is datetime
    df.sort_values('Date', inplace=True)
    df.set_index('Date', inplace=True)
    
    stock_data[stock_name] = df

# Show sample data
stock_data["AAPL_historical_data"].head()
# Out:
#                 Open      High       Low     Close  Adj Close     Volume  \
# Date
# 1980-12-12  0.128348  0.128906  0.128348  0.128348   0.098943  469033600
# 1980-12-15  0.122210  0.122210  0.121652  0.121652   0.093781  175884800
# 1980-12-16  0.113281  0.113281  0.112723  0.112723   0.086898  105728000
# 1980-12-17  0.115513  0.116071  0.115513  0.115513   0.089049   86441600
# 1980-12-18  0.118862  0.119420  0.118862  0.118862   0.091630   73449600
#
#             Dividends  Stock Splits
# Date
# 1980-12-12        0.0             0
# 1980-12-15        0.0             0
# 1980-12-16        0.0             0
# 1980-12-17        0.0             0
# 1980-12-18        0.0             0

# %%
# task_2_technical_indicators.ipynb

import pandas as pd
import ta  # install using: pip install ta
import matplotlib.pyplot as plt

# Example for one stock
df = stock_data["AAPL_historical_data"].copy()

# Add indicators
df['SMA_20'] = ta.trend.sma_indicator(df['Close'], window=20)
df['RSI'] = ta.momentum.rsi(df['Close'], window=14)
macd = ta.trend.macd(df['Close'])
df['MACD'] = macd.macd()
df['MACD_signal'] = macd.macd_signal()

# Plot example
plt.figure(figsize=(14, 6))
plt.plot(df.index, df['Close'], label='Close Price')
plt.plot(df.index, df['SMA_20'], label='SMA 20')
plt.title("AAPL Close Price with SMA")
plt.legend()
plt.grid()
plt.show()

# View the MACD section
df[['MACD', 'MACD_signal']].tail()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19860\3423161885.py in ?()
#      10 # Add indicators
#      11 df['SMA_20'] = ta.trend.sma_indicator(df['Close'], window=20)
#      12 df['RSI'] = ta.momentum.rsi(df['Close'], window=14)
#      13 macd = ta.trend.macd(df['Close'])
# ---> 14 df['MACD'] = macd.macd()
#      15 df['MACD_signal'] = macd.macd_signal()
#      16
#      17 # Plot example
#
# ~\week-1\venv\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'macd'
